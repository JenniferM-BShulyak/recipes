# %% [markdown]
# # Cut original data files
#
# recipes.csv and reviews.csv need to be cut down to under 100MB in order to upload in GitHub
#
# Unnecessary fields will be cut
#
# Publication dates before 2013 will be cut so only 10 years of data will remain and reviews will represent a larger portion of the population and computers, smartphones, and the internet became more ubiquitous

# %%
# import dependencies
import pandas as pd
import datetime as dt
import numpy as np

# %% [markdown]
# # Reviews Data

# %%
# Import reviews csv
reviews_raw = pd.read_csv("../og_files/reviews.csv")
reviews_raw.head(5)
# Out:
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
#
#                                               Review         DateSubmitted  \
# 0       better than any you can get at a restaurant!  2000-01-25T21:44:00Z
# 1  I cut back on the mayo, and made up the differ...  2001-10-17T16:49:59Z
# 2  i think i did something wrong because i could ...  2000-02-25T09:00:00Z
# 3  easily the best i have ever had.  juicy flavor...  2000-03-13T21:15:00Z
# 4                                 An excellent dish.  2000-03-28T12:51:00Z
#
#            DateModified
# 0  2000-01-25T21:44:00Z
# 1  2001-10-17T16:49:59Z
# 2  2000-02-25T09:00:00Z
# 3  2000-03-13T21:15:00Z
# 4  2000-03-28T12:51:00Z

# %%
# Check datatypes; Want DateSubmitted to be in datetime
reviews_raw.dtypes
# Out:
# ReviewId          int64
# RecipeId          int64
# AuthorId          int64
# AuthorName       object
# Rating            int64
# Review           object
# DateSubmitted    object
# DateModified     object
# dtype: object

# %%
# DateSubmitted is a string object and needs to be cast in datetime
reviews_raw = reviews_raw.astype({"DateSubmitted": "datetime64"})

# %%
# Cut the data to be 2013 or later so that there will only be 10 years of data
reviews_cut = reviews_raw.loc[(reviews_raw["DateSubmitted"]>np.datetime64('2013-01-01')),:]

# %%
# Export the cut reviews DataFrame as a CSV file. 
reviews_cut.to_csv("Resources/reviews_cut_2013.csv", encoding='utf8', index=False)

# %% [markdown]
# # Recipes Data

# %%
# Import recipes csv
recipes_raw = pd.read_csv("../og_files/recipes.csv")
recipes_raw.head(5)
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# 2  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 3  c("https://img.sndimg.com/food/image/upload/w_...  ...                 3.8
# 4  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 28 columns]

# %%
recipes_raw.columns
# Out:
# Index(['RecipeId', 'Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
#        'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeCategory',
#        'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions'],
#       dtype='object')

# %%
# Cut out unnecessary columns: "Images", "RecipeInstructions", "RecipeYield", "RecipeInstructions", "Keywords", 'RecipeIngredientQuantities', 'RecipeIngredientParts', 'Description'
recipes_cut = recipes_raw.drop(columns=["Images", "AuthorName", "RecipeYield", "RecipeInstructions", "Keywords", 'RecipeIngredientQuantities', 'RecipeIngredientParts', 'Description'])
recipes_cut.head(5)
# Out:
#    RecipeId                               Name  AuthorId CookTime PrepTime  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533    PT24H    PT45M
# 1        39                            Biryani      1567    PT25M     PT4H
# 2        40                      Best Lemonade      1566     PT5M    PT30M
# 3        41     Carina's Tofu-Vegetable Kebabs      1586    PT20M    PT24H
# 4        42                       Cabbage Soup      1538    PT30M    PT20M
#
#   TotalTime         DatePublished   RecipeCategory  AggregatedRating  \
# 0  PT24H45M  1999-08-09T21:46:00Z  Frozen Desserts               4.5
# 1   PT4H25M  1999-08-29T13:12:00Z   Chicken Breast               3.0
# 2     PT35M  1999-09-05T19:52:00Z        Beverages               4.5
# 3  PT24H20M  1999-09-03T14:54:00Z         Soy/Tofu               4.5
# 4     PT50M  1999-09-19T06:19:00Z        Vegetable               4.5
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 0          4.0     170.9         2.5                  1.3                 8.0
# 1          1.0    1110.7        58.8                 16.6               372.8
# 2         10.0     311.1         0.2                  0.0                 0.0
# 3          2.0     536.1        24.0                  3.8                 0.0
# 4         11.0     103.6         0.4                  0.1                 0.0
#
#    SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# 0           29.8                 37.1           3.6          30.2
# 1          368.4                 84.4           9.0          20.4
# 2            1.8                 81.5           0.4          77.2
# 3         1558.6                 64.2          17.3          32.1
# 4          959.3                 25.1           4.8          17.7
#
#    ProteinContent  RecipeServings
# 0             3.2             4.0
# 1            63.4             6.0
# 2             0.3             4.0
# 3            29.3             2.0
# 4             4.3             4.0

# %%
# Check types of columns. We want datepublished to be in datetime64
recipes_cut.dtypes
# Out:
# RecipeId                        int64
# Name                           object
# AuthorId                        int64
# CookTime                       object
# PrepTime                       object
# TotalTime                      object
# DatePublished          datetime64[ns]
# RecipeCategory                 object
# AggregatedRating              float64
# ReviewCount                   float64
# Calories                      float64
# FatContent                    float64
# SaturatedFatContent           float64
# CholesterolContent            float64
# SodiumContent                 float64
# CarbohydrateContent           float64
# FiberContent                  float64
# SugarContent                  float64
# ProteinContent                float64
# RecipeServings                float64
# dtype: object

# %%
# Check types of columns. We want datepublished to be in datetime64
recipes_cut= recipes_cut.astype({"DatePublished": "datetime64"})
recipes_cut.dtypes
# Out:
# RecipeId                        int64
# Name                           object
# AuthorId                        int64
# CookTime                       object
# PrepTime                       object
# TotalTime                      object
# DatePublished          datetime64[ns]
# RecipeCategory                 object
# AggregatedRating              float64
# ReviewCount                   float64
# Calories                      float64
# FatContent                    float64
# SaturatedFatContent           float64
# CholesterolContent            float64
# SodiumContent                 float64
# CarbohydrateContent           float64
# FiberContent                  float64
# SugarContent                  float64
# ProteinContent                float64
# RecipeServings                float64
# dtype: object

# %%
# Cut the data to be 2013 or later so that there will only be 10 years of data
recipes_cut_2 = recipes_cut.loc[(recipes_cut["DatePublished"]>np.datetime64('2013-01-01')),:]

# %%
# Export the cut reviews DataFrame as a CSV file. 
recipes_cut_2.to_csv("Resources/recipes_cut_2013.csv", encoding='utf8', index=False)

# %% [markdown]
# # Recipes Keywords and Ingredients

# %%
recipes_ingrediants = recipes_raw.loc[(recipes_cut["DatePublished"]>np.datetime64('2013-01-01')), ['RecipeId', 'Name', 'TotalTime', 'DatePublished', 'RecipeCategory', 'Keywords', 'RecipeIngredientParts', 'AggregatedRating', 'ReviewCount']]

# %%
recipes_ingrediants
# Out:
#         RecipeId                                               Name TotalTime  \
# 127958    134437  Copycat Wendy&rsquo;s Spicy Chicken Fillet San...     PT50M
# 212104    221240            Copycat Red Lobster Nantucket Baked Cod     PT16M
# 240475    250325               Copycat Jimmy Dean Breakfast Sausage    PT3H8M
# 433189    449227  Copycat Panera Bread Spinach &amp; Artichoke S...     PT50M
# 475190    492718                                        Tamale Hash     PT13M
# ...          ...                                                ...       ...
# 522512    541379                     Meg's Fresh Ginger Gingerbread   PT1H35M
# 522513    541380   Roast Prime Rib au Poivre with Mixed Peppercorns   PT3H30M
# 522514    541381                              Kirshwasser Ice Cream      PT4H
# 522515    541382           Quick & Easy Asian Cucumber Salmon Rolls     PT15M
# 522516    541383                            Spicy Baked Scotch Eggs     PT40M
#
#                DatePublished  RecipeCategory  \
# 127958  2019-02-22T18:59:00Z    Lunch/Snacks
# 212104  2019-02-22T18:53:00Z  Very Low Carbs
# 240475  2019-02-22T19:02:00Z       Breakfast
# 433189  2019-02-22T18:57:00Z       Breakfast
# 475190  2013-01-01T06:30:00Z       Breakfast
# ...                      ...             ...
# 522512  2020-12-22T15:27:00Z         Dessert
# 522513  2020-12-22T15:32:00Z  Very Low Carbs
# 522514  2020-12-22T15:33:00Z       Ice Cream
# 522515  2020-12-22T22:11:00Z        Canadian
# 522516  2020-12-22T22:12:00Z       Breakfast
#
#                                             Keywords  \
# 127958  c("Chicken", "Poultry", "Meat", "< 60 Mins")
# 212104                                   "< 30 Mins"
# 240475                c("Pork", "Meat", "< 4 Hours")
# 433189                                   "< 60 Mins"
# 475190             c("Mexican", "< 15 Mins", "Easy")
# ...                                              ...
# 522512                                   "< 4 Hours"
# 522513  c("High Protein", "High In...", "< 4 Hours")
# 522514                     c("Dessert", "< 4 Hours")
# 522515                        c("< 15 Mins", "Easy")
# 522516                                   "< 60 Mins"
#
#                                     RecipeIngredientParts  AggregatedRating  \
# 127958  c("chicken breasts", "buttermilk", "all-purpos...               4.0
# 212104  c("olive oil", "cod fish fillets", "lemon juic...               NaN
# 240475  c("ground pork", "brown sugar", "light corn sy...               1.5
# 433189  c("unsalted butter", "all-purpose flour", "sal...               5.0
# 475190  c("onion", "garlic clove", "salsa", "Black-Eye...               5.0
# ...                                                   ...               ...
# 522512  c("fresh ginger", "unsalted butter", "dark bro...               NaN
# 522513  c("Dijon mustard", "garlic", "peppercorns", "s...               NaN
# 522514  c("half-and-half", "heavy cream", "brandy", "s...               NaN
# 522515  c("wasabi paste", "dill", "English cucumber", ...               NaN
# 522516  c("hard-boiled eggs", "breakfast sausage", "pa...               NaN
#
#         ReviewCount
# 127958          3.0
# 212104          1.0
# 240475          5.0
# 433189          1.0
# 475190          2.0
# ...             ...
# 522512          NaN
# 522513          NaN
# 522514          NaN
# 522515          NaN
# 522516          NaN
#
# [47331 rows x 9 columns]

# %%
# Export the cut recipes DataFrame as a CSV file. 
recipes_ingrediants.to_csv("Resources/recipes_ingredients_2013.csv", encoding='utf8', index=False)
